# %%
import pandas as pd

df_ground_truth = pd.read_csv("ground_truth-new.csv")
ground_truth = df_ground_truth.to_dict(orient="records")

# %%
from ingest import load_faq_data, build_index

documents = load_faq_data()

documents_llm = []

for doc in documents:
    if doc["course"] == "llm-zoomcamp":
        documents_llm.append(doc)

documents = documents_llm
index = build_index(documents)

# %%
doc_idx = {}

for doc in documents:
    doc_idx[doc["doc_id"]] = doc

# %%
from dotenv import load_dotenv
from openai import OpenAI
from toyaikit.llm import OpenAIClient

load_dotenv()
openai_client = OpenAI(
    base_url="https://api.openai.com/v1",
    api_key="api")

# %%
def search(query: str) -> list[dict]:
    """
    Search the FAQ database for entries matching the given query.
    """
    return index.search(
        query,
        num_results=5,
        boost_dict={"question": 1.0, "answer": 2.0, "section": 0.1},
        filter_dict={"course": "llm-zoomcamp"}
    )

# %%
from toyaikit.tools import Tools
from toyaikit.chat.runners import OpenAIResponsesRunner

agent_tools = Tools()
agent_tools.add_tool(search)

instructions = """
You're a course teaching assistant. Answer student questions based on
the FAQ search results. Use the search tool before answering.
""".strip()

runner = OpenAIResponsesRunner(
    tools=agent_tools,
    developer_prompt=instructions,
    llm_client=OpenAIClient(model="gpt-5.4-mini")
)

# %%
rec = ground_truth[0]

result = runner.loop(prompt=rec["question"])

# %%
result.all_messages
# Out:
# [EasyInputMessage(content="You're a course teaching assistant. Answer student questions based on\nthe FAQ search results. Use the search tool before answering.", role='developer', phase=None, type=None),
#  EasyInputMessage(content='I just found this course — is it still okay to join now?', role='user', phase=None, type=None),
#  ResponseFunctionToolCall(arguments='{"query":"join course late still okay enroll after start FAQ"}', call_id='call_nG5kL5NKsGzE14Tg5ZAAnrmc', name='search', type='function_call', id='fc_057e47f7cdba06df006a549f107348819dbe58aae2068765fe', namespace=None, status='completed'),
#  {'type': 'function_call_output',
#   'call_id': 'call_nG5kL5NKsGzE14Tg5ZAAnrmc',
#   'output': '[\n  {\n    "course": "llm-zoomcamp",\n    "section": "General Course-Related Questions",\n    "question": "I just discovered the course. Can I still join?",\n    "answer": "Yes, but if you want to receive a certificate, you need to submit your project while we\\u2019re still accepting submissions.",\n    "doc_id": "74eb249bbf"\n  },\n  {\n    "course": "llm-zoomcamp",\n    "section": "General Course-Related Questions",\n    "question": "The homework submission form is still open even though the deadline has passed \\u2014 can I still submit?",\n    "answer": "Yes. As long as the submission form is still open, you can submit your answers, even if the listed deadline has already passed. You can no longer submit only after the form has been closed \\u2014 so while it\'s still open, go ahead and submit.",\n    "doc_id": "a9353fadfe"\n  },\n  {\n    "course": "llm-zoomcamp",\n    "section": "General Course-Related Questions",\n    "question": "Can I submit homework after the deadline, or get a deadline extension?",\n    "answer": "No. We don\'t give individual deadline extensions, and once the homework submission form is closed you can no longer submit it \\u2014 there are no late submissions. While the form is still open you can submit, even if the listed deadline has already passed.\\n\\nMissing a homework won\'t affect your certificate: homework isn\'t mandatory, only passing the Capstone project is. Homework points only count toward your leaderboard rank, so you\'ll still appear on the leaderboard with your other submissions.",\n    "doc_id": "cdc3b285e5"\n  },\n  {\n    "course": "llm-zoomcamp",\n    "section": "General Course-Related Questions",\n    "question": "How should I start the course and follow the weekly workflow?",\n    "answer": "Start with the [LLM Zoomcamp docs](https://datatalks.club/docs/courses/llm-zoomcamp/), the [general Zoomcamp logistics docs](https://datatalks.club/docs/courses/zoomcamp-logistics/), and the [LLM Zoomcamp GitHub repository](https://github.com/DataTalksClub/llm-zoomcamp).\\n\\nYou can start whenever you want. The videos and GitHub materials are available, and the deadlines are listed in the [course management platform](https://courses.datatalks.club/llm-zoomcamp-2026/).\\n\\nA typical workflow is:\\n\\n1. Watch the lesson videos.\\n2. Work through the lesson notebooks/code.\\n3. Read the homework instructions on GitHub.\\n4. Submit answers through the course platform before the deadline.\\n\\nHomework is similar to the lesson flow, but uses a different dataset or slightly different task.",\n    "doc_id": "04919992b3"\n  },\n  {\n    "course": "llm-zoomcamp",\n    "section": "General Course-Related Questions",\n    "question": "Why doesn\'t the number of records I get in the FAQ dataset match the videos?",\n    "answer": "We load the data from the live FAQ dataset, which changes over time: new questions are added and old ones are deleted. The videos were recorded in May 2026, so by the time you run the code the count is different from what you see in the videos.",\n    "doc_id": "e2d595f23c"\n  }\n]'},
#  ResponseOutputMessage(id='msg_057e47f7cdba06df006a549f125008819d80119d12a2ec5b2d', content=[ResponseOutputText(annotations=[], text='Yes — you can still join now.\n\nAccording to the course FAQ, if you just discovered the course, you can join anytime. The only catch is that if you want a certificate, you need to submit your project while submissions are still being accepted.\n\n', type='output_text', logprobs=[])], role='assistant', status='completed', type='message', phase='final_answer')]

# %%
def extract_tool_calls(messages):
    tool_calls = []

    for message in messages:
        if isinstance(message, dict):
            continue

        if message.type == "function_call":
            tool_calls.append({
                "name": message.name,
                "arguments": message.arguments,
            })

    return tool_calls

# %%
tool_calls = extract_tool_calls(result.all_messages)

tool_calls
# Out:
# [{'name': 'search',
#   'arguments': '{"query":"join course late still okay enroll after start FAQ"}'}]

# %%
doc_id = rec["document"]
original_doc = doc_idx[doc_id]
answer_orig = original_doc["answer"]

# %%
agent_result = {
    "question": rec["question"],
    "answer_agent": result.last_message,
    "answer_orig": answer_orig,
    "tool_calls": tool_calls,
    "cost": result.cost.total_cost,
    "document": doc_id,
}

agent_result
# Out:
# {'question': 'I just found this course — is it still okay to join now?',
#  'answer_agent': 'Yes — you can still join now.\n\nAccording to the course FAQ, if you just discovered the course, you can join anytime. The only catch is that if you want a certificate, you need to submit your project while submissions are still being accepted.\n\n',
#  'answer_orig': 'Yes, but if you want to receive a certificate, you need to submit your project while we’re still accepting submissions.',
#  'tool_calls': [{'name': 'search',
#    'arguments': '{"query":"join course late still okay enroll after start FAQ"}'}],
#  'cost': Decimal('0.0010815'),
#  'document': '74eb249bbf'}

# %%
def generate_agent_answer(rec):
    doc_id = rec["document"]
    original_doc = doc_idx[doc_id]

    result = runner.loop(prompt=rec["question"])

    tool_calls = extract_tool_calls(result.all_messages)

    answer_record = {
        "question": rec["question"],
        "answer_agent": result.last_message,
        "answer_orig": original_doc["answer"],
        "tool_calls": tool_calls,
        "cost": result.cost.total_cost,
        "document": doc_id,
    }

    return answer_record

# %%
from concurrent.futures import ThreadPoolExecutor
from evaluation_utils import map_progress

with ThreadPoolExecutor(max_workers=6) as pool:
    agent_answers = map_progress(pool, ground_truth[:50], generate_agent_answer)
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]

# %%
df_agent = pd.DataFrame(agent_answers)

# %%
df_agent["cost"].sum()
# Out:
# np.float64(0.06476025)

# %%
df_agent.to_csv("agent-answers.csv", index=False)

# %%
df_agent = pd.read_csv("agent-answers.csv")
agent_answers = df_agent.to_dict(orient="records")
agent_answers
# Out:
# [{'question': 'I just found this course — is it still okay to join now?',
#   'answer_agent': 'Yes — you can still join now. The course materials are available and you can start anytime.\n\nA couple of notes:\n- You can begin learning and, if homework submission forms are still open, you can submit homework even if a listed deadline has passed.\n- If you want a certificate, make sure you submit the project while submissions are still being accepted.\n\nIf you want, I can also help you figure out the best way to catch up quickly.',
#   'answer_orig': 'Yes, but if you want to receive a certificate, you need to submit your project while we’re still accepting submissions.',
#   'tool_calls': '[{\'name\': \'search\', \'arguments\': \'{"query":"join course late still okay enroll after start late registration attendance participation FAQ"}\'}]',
#   'cost': 0.0012795,
#   'document': '74eb249bbf'},
#  {'question': 'Can I start the course late, or is it already too far along?',
#   'answer_agent': 'Yes — you can start the course late.\n\nThe FAQ says you can join whenever you want, and the videos/GitHub materials are available. If you’re just looking to learn, you can follow along at your own pace.\n\nA couple of caveats:\n- If you want a certificate, you need to complete the course with the live cohort and submit your capstone while submissions are still open.\n- Homework has no late submissions once the form closes, but if the form is still open, you can still submit even after the listed deadline.\n\nIf you want, I can also tell you how to track the current syllabus, deadlines, and progress.',
#   'answer_orig': 'Yes, but if you want to receive a certificate, you need to submit your project while we’re still accepting submissions.',
#   'tool_calls': '[{\'name\': \'search\', \'arguments\': \'{"query":"start the course late too far along late enrollment join late course already in progress"}\'}]',
#   'cost': 0.00149925,
#   'document': '74eb249bbf'},
#  {'question': 'If I join now, will I still be able to get a certificate somehow?',
#   'answer_agent': 'Yes — you can still join, but to get a certificate you need to submit your project while the course is still accepting submissions.\n\nAlso, certificates are only available for the live cohort, not the self-paced mode.',
#   'answer_orig': 'Yes, but if you want to receive a certificate, you need to submit your project while we’re still accepting submissions.',
#   'tool_calls': '[{\'name\': \'search\', \'arguments\': \'{"query":"join now certificate still able get certificate somehow"}\'}]',
#   'cost': 0.000996,
#   'document': '74eb249bbf'},
#  {'question': 'What do I need to do to qualify for the certificate if I’m coming in late?',
#   'answer_agent': 'If you’re coming in late, you can still qualify for the certificate as long as you **finish the course with the live cohort** and **pass the Capstone project**.\n\nA few important points:\n- **Homework is not required** for the certificate.\n- **You cannot get a certificate in self-paced mode**.\n- You also need to be able to **peer-review 3 capstone projects** after submitting your own, which is only possible while the course is running.\n\nIf you want, I can also summarize what “coming in late” means for homework and deadlines.',
#   'answer_orig': 'Yes, but if you want to receive a certificate, you need to submit your project while we’re still accepting submissions.',
#   'tool_calls': '[{\'name\': \'search\', \'arguments\': \'{"query":"certificate qualify late enrollment coming in late attendance requirements FAQ"}\'}]',
#   'cost': 0.00136875,
#   'document': '74eb249bbf'},
#  {'question': 'Is it too late to participate, or can I still submit the project for certification?',
#   'answer_agent': 'You can still submit **if the project submission window is still open**. If the form has been closed, then it’s too late.\n\nAlso, for certification:\n- You need to **complete the Capstone project**\n- And **participate in peer review of 3 peers** in your cohort\n\nIf you want, I can also help you figure out whether your specific submission window is still open.',
#   'answer_orig': 'Yes, but if you want to receive a certificate, you need to submit your project while we’re still accepting submissions.',
#   'tool_calls': '[{\'name\': \'search\', \'arguments\': \'{"query":"too late participate submit project for certification deadline certification project late"}\'}]',
#   'cost': 0.0012075,
#   'document': '74eb249bbf'},
#  {'question': 'I signed up for LLM Zoomcamp, but I never got a confirmation email. Do I still need to wait for it before starting the course?',
#   'answer_agent': 'No—you don’t need to wait for the confirmation email. The FAQ says you’re already accepted, and you can start learning and submitting homework while the form is open. Registration is only used to gauge interest, not to check against an approved list.\n\nIf you want, I can also point you to the best place to start the course.',
#   'answer_orig': "You don't need it. You're accepted. You can also just start learning and submitting homework (while the form is open) without registering. It is not checked against any registered list. Registration is just to gauge interest before the start date.",
#   'tool_calls': '[{\'name\': \'search\', \'arguments\': \'{"query":"confirmation email signup no confirmation email wait before starting course LLM Zoomcamp"}\'}]',
#   'cost': 0.00126825,
#   'document': '977bf7786c'},
#  {'question': 'Is there some approval or acceptance email I’m supposed to get after registering for the LLM Zoomcamp?',
#   'answer_agent': 'You don’t need an approval or acceptance email. If you registered for the LLM Zoomcamp, you’re already accepted.\n\nAlso, registration isn’t checked against a list, so you can start learning and submit homework while the form is open even without registering. Registration is mainly just to gauge interest before the start date.',
#   'answer_orig': "You don't need it. You're accepted. You can also just start learning and submitting homework (while the form is open) without registering. It is not checked against any registered list. Registration is just to gauge interest before the start date.",
#   'tool_calls': '[{\'name\': \'search\', \'arguments\': \'{"query":"approval acceptance email after registering for the LLM Zoomcamp registration confirmation email"}\'}]',
#   'cost': 0.00138975,
#   'document': '977bf7786c'},
#  {'question': 'Do I have to be on a registered list to watch the lessons and submit homework, or can I just start?',
#   'answer_agent': 'No — you don’t need to be on a registered list.\n\nYou can just start learning, watch the lessons, and submit homework as long as the submission form is open. Registration is only used to gauge interest before the course starts, and it is not checked against a list.',
#   'answer_orig': "You don't need it. You're accepted. You can also just start learning and submitting homework (while the form is open) without registering. It is not checked against any registered list. Registration is just to gauge interest before the start date.",
#   'tool_calls': '[{\'name\': \'search\', \'arguments\': \'{"query":"registered list watch lessons submit homework start FAQ"}\'}]',
#   'cost': 0.0011925,
#   'document': '977bf7786c'},
#  {'question': 'What’s the point of the registration form for LLM Zoomcamp if it doesn’t affect access to the course?',
#   'answer_agent': 'The registration form is mainly there to **gauge interest before the course starts**.\n\nYou **don’t need to wait for confirmation** to access the course — you’re considered accepted, and you can start learning and submitting homework while the form is open. It’s **not checked against a registered list**.',
#   'answer_orig': "You don't need it. You're accepted. You can also just start learning and submitting homework (while the form is open) without registering. It is not checked against any registered list. Registration is just to gauge interest before the start date.",
#   'tool_calls': '[{\'name\': \'search\', \'arguments\': \'{"query":"registration form LLM Zoomcamp doesn\\\'t affect access to the course point of registration form"}\'}]',
#   'cost': 0.00121725,
#   'document': '977bf7786c'},
#  {'question': 'Can I begin learning and turning in homework for LLM Zoomcamp even if I only registered and didn’t receive any email back?',
#   'answer_agent': 'Yes — you can start learning and submitting homework even if you only registered and never got a confirmation email.\n\nAccording to the FAQ:\n- You **don’t need the email**.\n- **Registration is just to gauge interest**.\n- You’re **accepted**.\n- You can **start learning and submit homework** as long as the submission form is open.\n- It’s **not checked against a registered list**.\n\nIf you want, I can also point you to the course platform and homework links.',
#   'answer_orig': "You don't need it. You're accepted. You can also just start learning and submitting homework (while the form is open) without registering. It is not checked against any registered list. Registration is just to gauge interest before the start date.",
#   'tool_calls': '[{\'name\': \'search\', \'arguments\': \'{"query":"registered didn\\\'t receive email back begin learning turning in homework LLM Zoomcamp"}\'}]',
#   'cost': 0.001287,
#   'document': '977bf7786c'},
#  {'question': 'Where do students join the Office Hours or live workshop if the Zoom link isn’t shared with everyone?',
#   'answer_agent': 'Students join via **YouTube Live**, not the Zoom room.\n\n- The **Zoom link is only for instructors/presenters/TAs**.\n- The **YouTube Live URL** is posted in the **announcements channel on Telegram and Slack** before the session starts.\n- Questions should be submitted via **Slido** (the link is pinned in chat when live).\n\nYou can also watch on the **DataTalksClub YouTube channel**.',
#   'answer_orig': 'The zoom link is only published to instructors/presenters/TAs.\n\nStudents participate via YouTube Live and submit questions to Slido (link is pinned in the chat when live). The video URL should be posted in the [announcements channel on Telegram and Slack](https://t.me/dezoomcamp) before it begins. You can also watch live on the DataTalksClub [YouTube Channel](https://www.youtube.com/c/DataTalksClub).\n\nDon’t post questions in chat as they may be missed if the room is very active.',
#   'tool_calls': '[{\'name\': \'search\', \'arguments\': \'{"query":"Office Hours live workshop Zoom link not shared with everyone where do students join"}\'}]',
#   'cost': 0.0013635,
#   'document': '489dd1c9d9'},
#  {'question': 'How can I watch the live workshop stream if I’m not an instructor or TA?',
#   'answer_agent': 'If you’re not an instructor, presenter, or TA, you can’t use the Zoom link directly. Instead, watch the workshop live on the DataTalksClub YouTube channel, and check the announcements channel on Telegram or Slack for the video URL before it starts.',
#   'answer_orig': 'The zoom link is only published to instructors/presenters/TAs.\n\nStudents participate via YouTube Live and submit questions to Slido (link is pinned in the chat when live). The video URL should be posted in the [announcements channel on Telegram and Slack](https://t.me/dezoomcamp) before it begins. You can also watch live on the DataTalksClub [YouTube Channel](https://www.youtube.com/c/DataTalksClub).\n\nDon’t post questions in chat as they may be missed if the room is very active.',
#   'tool_calls': '[{\'name\': \'search\', \'arguments\': \'{"query":"live workshop stream not instructor TA watch access"}\'}]',
#   'cost': 0.00122325,
#   'document': '489dd1c9d9'},
#  {'question': 'Is the Zoom link for office hours posted anywhere for students, or only for staff?',
#   'answer_agent': 'The Zoom link is **only published to instructors/presenters/TAs**, not to students.\n\nFor students, the session is typically shared via:\n- **YouTube Live**\n- **Slido** for questions\n- the **announcements channel on Telegram and Slack** before it begins\n\nIf you want, I can also tell you where the live session/video link is usually posted.',
#   'answer_orig': 'The zoom link is only published to instructors/presenters/TAs.\n\nStudents participate via YouTube Live and submit questions to Slido (link is pinned in the chat when live). The video URL should be posted in the [announcements channel on Telegram and Slack](https://t.me/dezoomcamp) before it begins. You can also watch live on the DataTalksClub [YouTube Channel](https://www.youtube.com/c/DataTalksClub).\n\nDon’t post questions in chat as they may be missed if the room is very active.',
#   'tool_calls': '[{\'name\': \'search\', \'arguments\': \'{"query":"Zoom link office hours posted students staff FAQ"}\'}]',
#   'cost': 0.001332,
#   'document': '489dd1c9d9'},
#  {'question': 'Where do I find the live video link for the workshop before it starts?',
#   'answer_agent': 'The live video link is usually posted in the **announcements channel on Telegram and Slack before the session starts**.\n\nYou can also watch it live on the **DataTalksClub YouTube channel**. The Zoom link itself is only for instructors/presenters/TAs.',
#   'answer_orig': 'The zoom link is only published to instructors/presenters/TAs.\n\nStudents participate via YouTube Live and submit questions to Slido (link is pinned in the chat when live). The video URL should be posted in the [announcements channel on Telegram and Slack](https://t.me/dezoomcamp) before it begins. You can also watch live on the DataTalksClub [YouTube Channel](https://www.youtube.com/c/DataTalksClub).\n\nDon’t post questions in chat as they may be missed if the room is very active.',
#   'tool_calls': '[{\'name\': \'search\', \'arguments\': \'{"query":"live video link workshop before it starts where find"}\'}]',
#   'cost': 0.00119775,
#   'document': '489dd1c9d9'},
#  {'question': 'What’s the best way for students to ask questions during the live session instead of posting in chat?',
#   'answer_agent': 'The best way is to use **Slido** during the live session. The Slido link is usually **pinned in the chat when the session is live**.\n\nA couple of notes:\n- **Don’t post questions in the chat** — they may get missed if the room is busy.\n- You can also follow the live session on **YouTube Live**.\n\nIf you want, I can also tell you where the live session link is usually announced.',
#   'answer_orig': 'The zoom link is only published to instructors/presenters/TAs.\n\nStudents participate via YouTube Live and submit questions to Slido (link is pinned in the chat when live). The video URL should be posted in the [announcements channel on Telegram and Slack](https://t.me/dezoomcamp) before it begins. You can also watch live on the DataTalksClub [YouTube Channel](https://www.youtube.com/c/DataTalksClub).\n\nDon’t post questions in chat as they may be missed if the room is very active.',
#   'tool_calls': '[{\'name\': \'search\', \'arguments\': \'{"query":"best way for students to ask questions during the live session instead of posting in chat"}\'}]',
#   'cost': 0.00146925,
#   'document': '489dd1c9d9'},
#  {'question': 'How do I begin LLM Zoomcamp and what should I read first?',
#   'answer_agent': 'To begin LLM Zoomcamp, start with these three places:\n\n1. **LLM Zoomcamp docs**  \n2. **General Zoomcamp logistics docs**  \n3. **LLM Zoomcamp GitHub repository**\n\nA typical order is:\n\n1. Watch the lesson videos  \n2. Work through the lesson notebooks/code  \n3. Read the homework instructions on GitHub  \n4. Submit answers on the course platform before the deadline\n\nIf you want to track syllabus, deadlines, and progress, use the **course management platform**.\n\nIf you tell me which week/module you’re starting with, I can point you to the exact first reading.',
#   'answer_orig': 'Start with the [LLM Zoomcamp docs](https://datatalks.club/docs/courses/llm-zoomcamp/), the [general Zoomcamp logistics docs](https://datatalks.club/docs/courses/zoomcamp-logistics/), and the [LLM Zoomcamp GitHub repository](https://github.com/DataTalksClub/llm-zoomcamp).\n\nYou can start whenever you want. The videos and GitHub materials are available, and the deadlines are listed in the [course management platform](https://courses.datatalks.club/llm-zoomcamp-2026/).\n\nA typical workflow is:\n\n1. Watch the lesson videos.\n2. Work through the lesson notebooks/code.\n3. Read the homework instructions on GitHub.\n4. Submit answers through the course platform before the deadline.\n\nHomework is similar to the lesson flow, but uses a different dataset or slightly different task.',
#   'tool_calls': '[{\'name\': \'search\', \'arguments\': \'{"query":"begin LLM Zoomcamp read first getting started first what should I read"}\'}]',
#   'cost': 0.00157125,
#   'document': '04919992b3'},
#  {'question': 'What’s the usual weekly workflow for this course after watching the videos?',
#   'answer_agent': 'A typical weekly workflow for the course is:\n\n1. Watch the lesson videos.\n2. Work through the lesson notebooks/code.\n3. Read the homework instructions on GitHub.\n4. Submit your answers through the course platform before the deadline.\n\nIf you want, I can also point you to the main course repo and docs to follow each week.',
#   'answer_orig': 'Start with the [LLM Zoomcamp docs](https://datatalks.club/docs/courses/llm-zoomcamp/), the [general Zoomcamp logistics docs](https://datatalks.club/docs/courses/zoomcamp-logistics/), and the [LLM Zoomcamp GitHub repository](https://github.com/DataTalksClub/llm-zoomcamp).\n\nYou can start whenever you want. The videos and GitHub materials are available, and the deadlines are listed in the [course management platform](https://courses.datatalks.club/llm-zoomcamp-2026/).\n\nA typical workflow is:\n\n1. Watch the lesson videos.\n2. Work through the lesson notebooks/code.\n3. Read the homework instructions on GitHub.\n4. Submit answers through the course platform before the deadline.\n\nHomework is similar to the lesson flow, but uses a different dataset or slightly different task.',
#   'tool_calls': '[{\'name\': \'search\', \'arguments\': \'{"query":"usual weekly workflow after watching the videos weekly workflow course videos"}\'}]',
#   'cost': 0.00124125,
#   'document': '04919992b3'},
#  {'question': 'Do I need to start on a specific date, or can I jump in whenever I want?',
#   'answer_agent': 'You can **start whenever you want** — the course materials and videos are available for self-paced learning.\n\nA couple of important caveats:\n- **Homework can only be submitted while the course form is open.**\n- If you want a **certificate**, you need to finish with the **live cohort**, not fully self-paced.\n\nIf you want, I can also tell you the recommended weekly workflow for starting the course.',
#   'answer_orig': 'Start with the [LLM Zoomcamp docs](https://datatalks.club/docs/courses/llm-zoomcamp/), the [general Zoomcamp logistics docs](https://datatalks.club/docs/courses/zoomcamp-logistics/), and the [LLM Zoomcamp GitHub repository](https://github.com/DataTalksClub/llm-zoomcamp).\n\nYou can start whenever you want. The videos and GitHub materials are available, and the deadlines are listed in the [course management platform](https://courses.datatalks.club/llm-zoomcamp-2026/).\n\nA typical workflow is:\n\n1. Watch the lesson videos.\n2. Work through the lesson notebooks/code.\n3. Read the homework instructions on GitHub.\n4. Submit answers through the course platform before the deadline.\n\nHomework is similar to the lesson flow, but uses a different dataset or slightly different task.',
#   'tool_calls': '[{\'name\': \'search\', \'arguments\': \'{"query":"start specific date jump in whenever want self-paced course enrollment start date"}\'}]',
#   'cost': 0.001461,
#   'document': '04919992b3'},
#  {'question': 'Where are the deadlines and homework submissions handled for LLM Zoomcamp?',
#   'answer_agent': 'For **LLM Zoomcamp**, deadlines and homework submissions are handled in the **course management platform**:\n\n- **Course platform:** https://courses.datatalks.club/llm-zoomcamp-2026/\n- It contains the **deadlines**, **homework submission form**, and **progress tracking**.\n\nYou can also find the **homework instructions** in the course GitHub repo, but **submission and deadlines are managed on the platform**.',
#   'answer_orig': 'Start with the [LLM Zoomcamp docs](https://datatalks.club/docs/courses/llm-zoomcamp/), the [general Zoomcamp logistics docs](https://datatalks.club/docs/courses/zoomcamp-logistics/), and the [LLM Zoomcamp GitHub repository](https://github.com/DataTalksClub/llm-zoomcamp).\n\nYou can start whenever you want. The videos and GitHub materials are available, and the deadlines are listed in the [course management platform](https://courses.datatalks.club/llm-zoomcamp-2026/).\n\nA typical workflow is:\n\n1. Watch the lesson videos.\n2. Work through the lesson notebooks/code.\n3. Read the homework instructions on GitHub.\n4. Submit answers through the course platform before the deadline.\n\nHomework is similar to the lesson flow, but uses a different dataset or slightly different task.',
#   'tool_calls': '[{\'name\': \'search\', \'arguments\': \'{"query":"LLM Zoomcamp deadlines homework submissions handled where"}\'}]',
#   'cost': 0.00137625,
#   'document': '04919992b3'},
#  {'question': 'Is the homework basically the same as the lesson notebooks, or is it different?',
#   'answer_agent': 'The homework usually **follows the lesson workflow**, but it’s often **not exactly the same** as the lesson notebooks.\n\nIn practice, it may:\n- use a **different dataset**,\n- ask you to apply the **same idea in a slightly different way**,\n- or include extra instructions in the **GitHub homework file**.\n\nSo the lesson notebooks are a good guide, but you should check the **GitHub homework instructions** too, since they often contain important extra context.',
#   'answer_orig': 'Start with the [LLM Zoomcamp docs](https://datatalks.club/docs/courses/llm-zoomcamp/), the [general Zoomcamp logistics docs](https://datatalks.club/docs/courses/zoomcamp-logistics/), and the [LLM Zoomcamp GitHub repository](https://github.com/DataTalksClub/llm-zoomcamp).\n\nYou can start whenever you want. The videos and GitHub materials are available, and the deadlines are listed in the [course management platform](https://courses.datatalks.club/llm-zoomcamp-2026/).\n\nA typical workflow is:\n\n1. Watch the lesson videos.\n2. Work through the lesson notebooks/code.\n3. Read the homework instructions on GitHub.\n4. Submit answers through the course platform before the deadline.\n\nHomework is similar to the lesson flow, but uses a different dataset or slightly different task.',
#   'tool_calls': '[{\'name\': \'search\', \'arguments\': \'{"query":"homework lesson notebooks same different homework notebooks"}\'}]',
#   'cost': 0.00148725,
#   'document': '04919992b3'},
#  {'question': "How do I find my name on the leaderboard if I can't see it right away?",
#   'answer_agent': 'If you can’t see your name right away on the leaderboard, click **“Jump to your record on the leaderboard”** — that takes you directly to your entry.\n\nAlso, when you set up your account, you’re automatically given a random display name. If you want to check or change it, go to **Edit Course Profile**:\n- **First field:** your public nickname/display name\n- **Second field:** your official name for the certificate\n\nIf you want, I can also explain how the leaderboard name differs from the certificate name.',
#   'answer_orig': 'When you set up your account, you are automatically assigned a random name, such as “Lucid Elbakyan.” Click on the "Jump to your record on the leaderboard" link to find your entry.\n\nIf you want to see what your Display name is, click on the "Edit Course Profile" button.\n\n<{IMAGE:image_1}>\n\n- **First field:** This is your nickname/displayed name. You can change it if you want to be known by your Slack username, GitHub username, or any other nickname of your choice. This is useful if you want to remain anonymous.\n- **Second field:** Change this to your official name as in your identification documents—passport, national ID card, driver\'s license, etc. This is mandatory if you do not want "Lucid Elbakyan" on your certificate. This name will appear on your Certificate!',
#   'tool_calls': '[{\'name\': \'search\', \'arguments\': \'{"query":"find my name on the leaderboard can\\\'t see it right away"}\'}]',
#   'cost': 0.00189075,
#   'document': 'c2903069a0'},
#  {'question': 'Why am I showing up under a random name on the leaderboard, and can I change it?',
#   'answer_agent': 'Yes — that random name is your **default public display name** on the leaderboard. It’s assigned automatically when you create your account.\n\nYou can change it in **Edit Course Profile**:\n- **First field:** your **leaderboard/display name** — change this to whatever nickname you want to appear publicly\n- **Second field:** your **official name** for the certificate\n\nSo if you want, you can replace the random nickname with your Slack/GitHub name or any other nickname, while keeping your real name for the certificate.',
#   'answer_orig': 'When you set up your account, you are automatically assigned a random name, such as “Lucid Elbakyan.” Click on the "Jump to your record on the leaderboard" link to find your entry.\n\nIf you want to see what your Display name is, click on the "Edit Course Profile" button.\n\n<{IMAGE:image_1}>\n\n- **First field:** This is your nickname/displayed name. You can change it if you want to be known by your Slack username, GitHub username, or any other nickname of your choice. This is useful if you want to remain anonymous.\n- **Second field:** Change this to your official name as in your identification documents—passport, national ID card, driver\'s license, etc. This is mandatory if you do not want "Lucid Elbakyan" on your certificate. This name will appear on your Certificate!',
#   'tool_calls': '[{\'name\': \'search\', \'arguments\': \'{"query":"leaderboard random name change it profile display name alias leaderboard name"}\'}]',
#   'cost': 0.00153975,
#   'document': 'c2903069a0'},
#  {'question': "Where do I check what display name I'm using in the course profile?",
#   'answer_agent': 'Go to **Edit Course Profile**. Your **display name / nickname** is the **first field** there.\n\nIf you’re checking the leaderboard, that’s the name shown publicly by default.',
#   'answer_orig': 'When you set up your account, you are automatically assigned a random name, such as “Lucid Elbakyan.” Click on the "Jump to your record on the leaderboard" link to find your entry.\n\nIf you want to see what your Display name is, click on the "Edit Course Profile" button.\n\n<{IMAGE:image_1}>\n\n- **First field:** This is your nickname/displayed name. You can change it if you want to be known by your Slack username, GitHub username, or any other nickname of your choice. This is useful if you want to remain anonymous.\n- **Second field:** Change this to your official name as in your identification documents—passport, national ID card, driver\'s license, etc. This is mandatory if you do not want "Lucid Elbakyan" on your certificate. This name will appear on your Certificate!',
#   'tool_calls': '[{\'name\': \'search\', \'arguments\': \'{"query":"display name course profile where check what display name I\\\'m using"}\'}]',
#   'cost': 0.00131475,
#   'document': 'c2903069a0'},
#  {'question': 'What should I do if I want my Slack or GitHub name to appear instead of the random one?',
#   'answer_agent': 'Go to **Edit Course Profile** and change the **first field** (your display name / nickname). You can set it to your **Slack username, GitHub username, or any nickname** you want.\n\nThe **second field** is for your **official name** and is used for your certificate.',
#   'answer_orig': 'When you set up your account, you are automatically assigned a random name, such as “Lucid Elbakyan.” Click on the "Jump to your record on the leaderboard" link to find your entry.\n\nIf you want to see what your Display name is, click on the "Edit Course Profile" button.\n\n<{IMAGE:image_1}>\n\n- **First field:** This is your nickname/displayed name. You can change it if you want to be known by your Slack username, GitHub username, or any other nickname of your choice. This is useful if you want to remain anonymous.\n- **Second field:** Change this to your official name as in your identification documents—passport, national ID card, driver\'s license, etc. This is mandatory if you do not want "Lucid Elbakyan" on your certificate. This name will appear on your Certificate!',
#   'tool_calls': '[{\'name\': \'search\', \'arguments\': \'{"query":"Slack GitHub name appear instead of random one"}\'}]',
#   'cost': 0.001314,
#   'document': 'c2903069a0'},
#  {'question': 'How do I make sure my real name is used on the certificate instead of the default name?',
#   'answer_agent': 'To make sure your real name appears on the certificate, go to **Edit Course Profile** and set the **second field** to your official name exactly as it appears on your ID/passport.\n\nA few notes:\n- The **first field** is your public display name / leaderboard nickname.\n- The **second field** is the name printed on your **certificate**.\n- If you leave it as the default random name (like “Lucid Elbakyan”), that default name may appear on the certificate.\n\nSo the key step is: **update the certificate name field before the certificate is generated**.',
#   'answer_orig': 'When you set up your account, you are automatically assigned a random name, such as “Lucid Elbakyan.” Click on the "Jump to your record on the leaderboard" link to find your entry.\n\nIf you want to see what your Display name is, click on the "Edit Course Profile" button.\n\n<{IMAGE:image_1}>\n\n- **First field:** This is your nickname/displayed name. You can change it if you want to be known by your Slack username, GitHub username, or any other nickname of your choice. This is useful if you want to remain anonymous.\n- **Second field:** Change this to your official name as in your identification documents—passport, national ID card, driver\'s license, etc. This is mandatory if you do not want "Lucid Elbakyan" on your certificate. This name will appear on your Certificate!',
#   'tool_calls': '[{\'name\': \'search\', \'arguments\': \'{"query":"certificate real name default name change name used on certificate"}\'}]',
#   'cost': 0.00157875,
#   'document': 'c2903069a0'},
#  {'question': 'Can I take the course at my own pace and still get the certificate, or is it only for the live cohort?',
#   'answer_agent': 'No — you can only get a certificate if you finish the course with a live cohort.\n\nThe FAQ says certificates are **not** awarded for self-paced mode, because you need to peer-review 3 capstones after submitting your project, and that peer-review process is only available while the course is running live.\n\nIf you want, I can also explain what the certificate requirements are in more detail.',
#   'answer_orig': 'No, you can only get a certificate if you finish the course with a "live" cohort.\n\nWe don\'t award certificates for the self-paced mode. The reason is you need to peer-review 3 capstone(s) after submitting your project.\n\nYou can only peer-review projects at the time the course is running; after the form is closed and the peer-review list is compiled.',
#   'tool_calls': '[{\'name\': \'search\', \'arguments\': \'{"query":"self-paced own pace certificate live cohort certificate live cohort FAQ"}\'}]',
#   'cost': 0.001299,
#   'document': '69d122f12e'},
#  {'question': 'If I finish everything in self-paced mode, will I still receive a certificate?',
#   'answer_agent': 'No — you can’t get a certificate in self-paced mode.\n\nThe FAQ says certificates are only awarded if you finish the course with a live cohort, because the certificate requires peer-reviewing capstones while the course is running.',
#   'answer_orig': 'No, you can only get a certificate if you finish the course with a "live" cohort.\n\nWe don\'t award certificates for the self-paced mode. The reason is you need to peer-review 3 capstone(s) after submitting your project.\n\nYou can only peer-review projects at the time the course is running; after the form is closed and the peer-review list is compiled.',
#   'tool_calls': '[{\'name\': \'search\', \'arguments\': \'{"query":"self-paced mode certificate finish everything receive a certificate"}\'}]',
#   'cost': 0.00101025,
#   'document': '69d122f12e'},
#  {'question': 'Why don’t you give certificates for the self-paced version of the course?',
#   'answer_agent': 'We don’t give certificates for the self-paced version because certificates require peer-reviewing 3 capstone projects, and that’s only possible while the live cohort is running.\n\nOnce the course ends, the peer-review form closes and the review list is compiled, so self-paced learners can’t complete that requirement.',
#   'answer_orig': 'No, you can only get a certificate if you finish the course with a "live" cohort.\n\nWe don\'t award certificates for the self-paced mode. The reason is you need to peer-review 3 capstone(s) after submitting your project.\n\nYou can only peer-review projects at the time the course is running; after the form is closed and the peer-review list is compiled.',
#   'tool_calls': '[{\'name\': \'search\', \'arguments\': \'{"query":"self-paced version certificates why not give certificates FAQ"}\'}]',
#   'cost': 0.0012045,
#   'document': '69d122f12e'},
#  {'question': 'Do I need to peer-review other students’ capstone projects to be eligible for the certificate?',
#   'answer_agent': 'Yes. For the certificate, you’re expected to peer-review 3 capstone projects after submitting your own project.\n\nA few important notes:\n- This is required for the certificate.\n- You can only review projects while the course is actively running.\n- After the submission deadline, projects are assigned to you for review; you can’t choose them yourself.\n\nIf you want, I can also summarize the full certificate requirements.',
#   'answer_orig': 'No, you can only get a certificate if you finish the course with a "live" cohort.\n\nWe don\'t award certificates for the self-paced mode. The reason is you need to peer-review 3 capstone(s) after submitting your project.\n\nYou can only peer-review projects at the time the course is running; after the form is closed and the peer-review list is compiled.',
#   'tool_calls': '[{\'name\': \'search\', \'arguments\': \'{"query":"peer-review other students capstone projects eligible for certificate"}\'}]',
#   'cost': 0.00116175,
#   'document': '69d122f12e'},
#  {'question': 'Can I do the project reviews after the course ends, or is that only possible while the cohort is running?',
#   'answer_agent': 'No — you can only do the peer project reviews while the course is running with a live cohort. After the review form closes and the peer-review list is compiled, you can’t complete them, so self-paced participation doesn’t qualify for a certificate.',
#   'answer_orig': 'No, you can only get a certificate if you finish the course with a "live" cohort.\n\nWe don\'t award certificates for the self-paced mode. The reason is you need to peer-review 3 capstone(s) after submitting your project.\n\nYou can only peer-review projects at the time the course is running; after the form is closed and the peer-review list is compiled.',
#   'tool_calls': '[{\'name\': \'search\', \'arguments\': \'{"query":"project reviews after course ends cohort running"}\'}]',
#   'cost': 0.00102375,
#   'document': '69d122f12e'},
#  {'question': 'If I skip the first homework, can I still earn the course certificate as long as I do the capstone?',
#   'answer_agent': 'Yes. According to the FAQ, homework is **not mandatory** for the certificate — you can still earn it as long as you **pass the Capstone project**.\n\nOne note: this applies to the **live cohort** version of the course, since certificates aren’t awarded for self-paced participation.',
#   'answer_orig': 'Yes, you need to pass the Capstone project to get the certificate. Homework is not mandatory, though it is recommended for reinforcing concepts, and the points awarded count towards your rank on the leaderboard.',
#   'tool_calls': '[{\'name\': \'search\', \'arguments\': \'{"query":"skip first homework still earn course certificate capstone only homework certificate"}\'}]',
#   'cost': 0.001152,
#   'document': '9f689c185f'},
#  {'question': 'Do I have to complete every homework to get a certificate, or is the capstone enough?',
#   'answer_agent': 'No — you do **not** have to complete every homework to get a certificate.\n\nFor **llm-zoomcamp**, the FAQ says:\n\n- **Homework is not mandatory**\n- You **only need to pass the Capstone project** to get the certificate\n- Homework points are mainly for your **leaderboard rank** and practice\n\nSo the **capstone is enough** for the certificate.',
#   'answer_orig': 'Yes, you need to pass the Capstone project to get the certificate. Homework is not mandatory, though it is recommended for reinforcing concepts, and the points awarded count towards your rank on the leaderboard.',
#   'tool_calls': '[{\'name\': \'search\', \'arguments\': \'{"query":"certificate homework capstone enough complete every homework required FAQ"}\'}]',
#   'cost': 0.00125175,
#   'document': '9f689c185f'},
#  {'question': 'What do I actually need to pass in order to receive the certificate for this course?',
#   'answer_agent': 'To get the certificate, you need to **pass the Capstone project**.\n\nA few important notes:\n- **Homework is not mandatory** for the certificate, though it’s recommended.\n- You also need to finish the course with a **live cohort** — **self-paced mode does not award certificates**.\n- Since the course requires **peer-reviewing 3 capstone projects**, you can only get the certificate while the course is actively running.\n\nIf you want, I can also summarize the exact certificate workflow step by step.',
#   'answer_orig': 'Yes, you need to pass the Capstone project to get the certificate. Homework is not mandatory, though it is recommended for reinforcing concepts, and the points awarded count towards your rank on the leaderboard.',
#   'tool_calls': '[{\'name\': \'search\', \'arguments\': \'{"query":"certificate requirements pass receive certificate course what needed to pass"}\'}]',
#   'cost': 0.00126075,
#   'document': '9f689c185f'},
#  {'question': 'Are homework assignments mandatory for certification, or are they just for practice and leaderboard points?',
#   'answer_agent': 'Homework assignments are **not mandatory for certification**. You only need to **pass the Capstone project** to get the certificate.\n\nHomework is mainly for:\n- **practice / reinforcing concepts**\n- **earning points toward the leaderboard**\n\nSo yes — they’re optional for certification, but useful for learning and ranking.',
#   'answer_orig': 'Yes, you need to pass the Capstone project to get the certificate. Homework is not mandatory, though it is recommended for reinforcing concepts, and the points awarded count towards your rank on the leaderboard.',
#   'tool_calls': '[{\'name\': \'search\', \'arguments\': \'{"query":"homework assignments mandatory certification practice leaderboard points"}\'}]',
#   'cost': 0.00122025,
#   'document': '9f689c185f'},
#  {'question': "If homework isn't required, what role does it play in the course besides helping me learn?",
#   'answer_agent': 'I couldn’t find an FAQ entry that directly answers that.\n\nThe closest homework-related guidance in the FAQ says homework is **not ready** until the form is open and the title no longer has `[DRAFT]`, and that working on it early is **at your own risk** because the final version may change.\n\nIf you want, I can help interpret the course policy more generally, but based on the FAQ search results, there isn’t a specific answer about homework’s role beyond learning.',
#   'answer_orig': 'Yes, you need to pass the Capstone project to get the certificate. Homework is not mandatory, though it is recommended for reinforcing concepts, and the points awarded count towards your rank on the leaderboard.',
#   'tool_calls': '[{\'name\': \'search\', \'arguments\': \'{"query":"homework not required role in course besides helping me learn"}\'}]',
#   'cost': 0.00140925,
#   'document': '9f689c185f'},
#  {'question': 'Why does the homework content keep changing before it’s out?',
#   'answer_agent': 'If the homework title contains `[DRAFT]`, it means it’s not ready yet, so the content can still change.\n\nThe homework is considered ready only when both are true:\n\n- The homework form is open on the course management platform\n- The homework title does **not** contain `[DRAFT]`\n\nUntil then, please treat the material as subject to change. Working on it early is possible, but it’s at your own risk because the final version may differ.',
#   'answer_orig': 'If the homework title contains `[DRAFT]`, it means the homework is not ready yet.\n\nThe homework is ready only when both are true:\n\n- The homework form is open on the course management platform.\n- The homework title does not contain `[DRAFT]`.\n\nUntil then, the content can still change. Working on the material or homework in advance is at your own risk, because the final version can be different.',
#   'tool_calls': '[{\'name\': \'search\', \'arguments\': \'{"query":"homework content keep changing before it’s out"}\'}]',
#   'cost': 0.0014175,
#   'document': '96286b4be4'},
#  {'question': 'What does it mean when the homework title has [DRAFT] in it?',
#   'answer_agent': 'If the homework title contains `[DRAFT]`, it means the homework is **not ready yet**.\n\nThe homework is considered ready only when:\n\n- the homework form is open on the course platform, and\n- the title no longer contains `[DRAFT]`.\n\nUntil then, the content may still change, so doing it early is at your own risk.',
#   'answer_orig': 'If the homework title contains `[DRAFT]`, it means the homework is not ready yet.\n\nThe homework is ready only when both are true:\n\n- The homework form is open on the course management platform.\n- The homework title does not contain `[DRAFT]`.\n\nUntil then, the content can still change. Working on the material or homework in advance is at your own risk, because the final version can be different.',
#   'tool_calls': '[{\'name\': \'search\', \'arguments\': \'{"query":"homework title [DRAFT] meaning"}\'}]',
#   'cost': 0.00131475,
#   'document': '96286b4be4'},
#  {'question': 'How can I tell if a homework is actually ready to do?',
#   'answer_agent': 'A homework is ready only when **both** of these are true:\n\n- The homework form is open on the course management platform.\n- The homework title does **not** contain **`[DRAFT]`**.\n\nIf the title still says `[DRAFT]`, the homework is not ready yet and the content may still change. Working on it early is at your own risk.',
#   'answer_orig': 'If the homework title contains `[DRAFT]`, it means the homework is not ready yet.\n\nThe homework is ready only when both are true:\n\n- The homework form is open on the course management platform.\n- The homework title does not contain `[DRAFT]`.\n\nUntil then, the content can still change. Working on the material or homework in advance is at your own risk, because the final version can be different.',
#   'tool_calls': '[{\'name\': \'search\', \'arguments\': \'{"query":"How can I tell if a homework is actually ready to do?"}\'}]',
#   'cost': 0.00141,
#   'document': '96286b4be4'},
#  {'question': 'Can the homework still change even if it’s already visible on the platform?',
#   'answer_agent': 'Yes — if the homework is still marked as **`[DRAFT]`**, it can still change even if it’s already visible on the platform.\n\nThe homework is considered **ready only when both are true**:\n- the homework form is open on the course management platform, and\n- the homework title **does not** contain **`[DRAFT]`**.\n\nSo if you see it but it’s still a draft, you should treat it as subject to change.',
#   'answer_orig': 'If the homework title contains `[DRAFT]`, it means the homework is not ready yet.\n\nThe homework is ready only when both are true:\n\n- The homework form is open on the course management platform.\n- The homework title does not contain `[DRAFT]`.\n\nUntil then, the content can still change. Working on the material or homework in advance is at your own risk, because the final version can be different.',
#   'tool_calls': '[{\'name\': \'search\', \'arguments\': \'{"query":"homework visible on platform still change assignment can change after posted"}\'}]',
#   'cost': 0.00129375,
#   'document': '96286b4be4'},
#  {'question': 'Is it safe to start the homework early, or could the final version be different?',
#   'answer_agent': 'Yes—working on homework early is **at your own risk**.\n\nIf the homework title includes **`[DRAFT]`**, it is **not ready yet**, and the final version can still change. The homework is only considered ready when:\n\n- the homework form is open on the course management platform, and\n- the homework title **does not** contain `[DRAFT]`.\n\nSo it’s safe only once those two conditions are met.',
#   'answer_orig': 'If the homework title contains `[DRAFT]`, it means the homework is not ready yet.\n\nThe homework is ready only when both are true:\n\n- The homework form is open on the course management platform.\n- The homework title does not contain `[DRAFT]`.\n\nUntil then, the content can still change. Working on the material or homework in advance is at your own risk, because the final version can be different.',
#   'tool_calls': '[{\'name\': \'search\', \'arguments\': \'{"query":"start homework early final version different safe homework early final version different"}\'}]',
#   'cost': 0.00146925,
#   'document': '96286b4be4'},
#  {'question': 'When is the next llm-zoomcamp course starting?',
#   'answer_agent': 'The FAQ says the next **LLM Zoomcamp** will be offered in **summer 2027**.',
#   'answer_orig': 'Summer 2027.',
#   'tool_calls': '[{\'name\': \'search\', \'arguments\': \'{"query":"next llm-zoomcamp course starting date"}\'}]',
#   'cost': 0.00092625,
#   'document': 'bd31146b0e'},
#  {'question': 'Do you know when this course will be offered again?',
#   'answer_agent': 'Yes — the course is scheduled to be offered again in **Summer 2027**.',
#   'answer_orig': 'Summer 2027.',
#   'tool_calls': '[{\'name\': \'search\', \'arguments\': \'{"query":"when course offered again next offering schedule next semester"}\'}]',
#   'cost': 0.0011535,
#   'document': 'bd31146b0e'},
#  {'question': 'What’s the next session date for llm-zoomcamp?',
#   'answer_agent': 'I couldn’t find a specific “next session date” in the FAQ results for LLM Zoomcamp.\n\nWhat the FAQ does say is that you can track the current cohort, deadlines, and progress on the course management platform:\nhttps://courses.datatalks.club/llm-zoomcamp-2026/\n\nIf you want, I can help look for a specific module/session or clarify where the live session schedule is listed.',
#   'answer_orig': 'Summer 2027.',
#   'tool_calls': '[{\'name\': \'search\', \'arguments\': \'{"query":"llm-zoomcamp next session date"}\'}]',
#   'cost': 0.0012885,
#   'document': 'bd31146b0e'},
#  {'question': 'When can I expect the course to run next?',
#   'answer_agent': 'The course is expected to run next in **Summer 2027**.',
#   'answer_orig': 'Summer 2027.',
#   'tool_calls': '[{\'name\': \'search\', \'arguments\': \'{"query":"When can I expect the course to run next? next offering schedule course run dates"}\'}]',
#   'cost': 0.000846,
#   'document': 'bd31146b0e'},
#  {'question': 'Is there a planned next offering of the course, and when is it?',
#   'answer_agent': 'Yes — the next planned offering is **Summer 2027**.',
#   'answer_orig': 'Summer 2027.',
#   'tool_calls': '[{\'name\': \'search\', \'arguments\': \'{"query":"planned next offering of the course when is it next offering upcoming course date"}\'}]',
#   'cost': 0.00104925,
#   'document': 'bd31146b0e'},
#  {'question': 'Where can I find the course videos for LLM Zoomcamp?',
#   'answer_agent': 'You can find the LLM Zoomcamp videos through the **LLM Zoomcamp GitHub repository**:  \nhttps://github.com/DataTalksClub/llm-zoomcamp\n\nOpen the **lesson folders** there—each lesson page has the relevant videos linked at the top. The repo is the main entry point and is usually more up to date than a YouTube playlist.',
#   'answer_orig': 'Use the [LLM Zoomcamp GitHub repository](https://github.com/DataTalksClub/llm-zoomcamp) as the main entry point.\n\nOpen the lesson folders in the repo. Each lesson page has the relevant videos linked at the top.\n\n<{IMAGE:lessons}>\n\nWhen in doubt, follow the GitHub repo first, because it is easier to keep updated than the YouTube playlist.',
#   'tool_calls': '[{\'name\': \'search\', \'arguments\': \'{"query":"LLM Zoomcamp course videos where can I find course videos"}\'}]',
#   'cost': 0.00125925,
#   'document': '31456f4b5f'},
#  {'question': 'Is there a main place I should open first to get the lecture links?',
#   'answer_agent': 'Yes — the main place to start is the **LLM Zoomcamp GitHub repository**.\n\nOpen the lesson folders there, and each lesson page has the relevant lecture/video links at the top. If you’re unsure, follow the GitHub repo first, since it’s usually more up to date than the YouTube playlist.\n\nIf you want, I can also point you to the exact repo page for your module.',
#   'answer_orig': 'Use the [LLM Zoomcamp GitHub repository](https://github.com/DataTalksClub/llm-zoomcamp) as the main entry point.\n\nOpen the lesson folders in the repo. Each lesson page has the relevant videos linked at the top.\n\n<{IMAGE:lessons}>\n\nWhen in doubt, follow the GitHub repo first, because it is easier to keep updated than the YouTube playlist.',
#   'tool_calls': '[{\'name\': \'search\', \'arguments\': \'{"query":"lecture links main place open first"}\'}]',
#   'cost': 0.00121125,
#   'document': '31456f4b5f'},
#  {'question': 'How do I know which videos go with each lesson in the repo?',
#   'answer_agent': 'Use the **LLM Zoomcamp GitHub repository** as the main source of truth.\n\n- Open the **lesson folders** in the repo.\n- **Each lesson page has the relevant videos linked at the top**.\n- If there’s any mismatch, **trust the GitHub repo first**, since it’s easier to keep updated than the YouTube playlist.\n\nIf you want, I can also help you find the specific lesson folder for a module.',
#   'answer_orig': 'Use the [LLM Zoomcamp GitHub repository](https://github.com/DataTalksClub/llm-zoomcamp) as the main entry point.\n\nOpen the lesson folders in the repo. Each lesson page has the relevant videos linked at the top.\n\n<{IMAGE:lessons}>\n\nWhen in doubt, follow the GitHub repo first, because it is easier to keep updated than the YouTube playlist.',
#   'tool_calls': '[{\'name\': \'search\', \'arguments\': \'{"query":"videos go with each lesson repo lesson videos mapping"}\'}]',
#   'cost': 0.00144375,
#   'document': '31456f4b5f'},
#  {'question': 'Do the lesson pages already include the relevant lecture videos?',
#   'answer_agent': 'Yes. The lesson pages already have the relevant lecture videos linked at the top of each lesson folder/page in the GitHub repo.\n\nBest place to start:\n- [LLM Zoomcamp GitHub repository](https://github.com/DataTalksClub/llm-zoomcamp)\n\nIf you’re unsure, follow the GitHub repo first since it’s usually updated more reliably than the YouTube playlist.',
#   'answer_orig': 'Use the [LLM Zoomcamp GitHub repository](https://github.com/DataTalksClub/llm-zoomcamp) as the main entry point.\n\nOpen the lesson folders in the repo. Each lesson page has the relevant videos linked at the top.\n\n<{IMAGE:lessons}>\n\nWhen in doubt, follow the GitHub repo first, because it is easier to keep updated than the YouTube playlist.',
#   'tool_calls': '[{\'name\': \'search\', \'arguments\': \'{"query":"lesson pages include lecture videos relevant lecture videos lesson pages"}\'}]',
#   'cost': 0.00128925,
#   'document': '31456f4b5f'},
#  {'question': 'Should I use the GitHub repo or the YouTube playlist to find the latest course lectures?',
#   'answer_agent': 'Use the **GitHub repo as the main entry point**. The FAQ says to open the lesson folders there, since each lesson page links the relevant videos at the top. It also notes that the repo is **easier to keep updated than the YouTube playlist**.\n\nSo for the latest lectures, follow the **GitHub repo first**.',
#   'answer_orig': 'Use the [LLM Zoomcamp GitHub repository](https://github.com/DataTalksClub/llm-zoomcamp) as the main entry point.\n\nOpen the lesson folders in the repo. Each lesson page has the relevant videos linked at the top.\n\n<{IMAGE:lessons}>\n\nWhen in doubt, follow the GitHub repo first, because it is easier to keep updated than the YouTube playlist.',
#   'tool_calls': '[{\'name\': \'search\', \'arguments\': \'{"query":"GitHub repo YouTube playlist latest course lectures"}\'}]',
#   'cost': 0.00132825,
#   'document': '31456f4b5f'}]

# %%
from pydantic import BaseModel, Field
from typing import Literal

class AgentEvaluation(BaseModel):
    answer_reasoning: str = Field(
        description="Reasoning about whether the final answer is correct."
    )
    answer_score: Literal["good", "bad"] = Field(
        description="'good' if the final answer matches the original answer."
    )
    trajectory_reasoning: str = Field(
        description="Reasoning about whether the tool calls were useful."
    )
    trajectory_score: Literal["good", "bad"] = Field(
        description="'good' if the tool calls were reasonable for the question."
    )

# %%
agent_judge_instructions = """
You are an expert evaluator. You will be given:
1. A question from a student
2. The original answer from the FAQ (ground truth)
3. An answer generated by an AI agent
4. The tool calls made by the agent

Evaluate two things:

Answer quality:
- Does the agent answer match the original answer?
- It does not need to be word-for-word identical.
- It should contain the same key information.

Trajectory quality:
- Were the search queries relevant to the question?
- Did the queries include important keywords from the question?
- Did the agent avoid duplicate or unnecessary tool calls?
- If it made multiple searches, did the later searches refine the query?
- Was the number of search calls reasonable? Usually 1 is enough, 2-3
  can be okay, and more than 3 needs a clear reason.
- Did the tool calls support the final answer?

Mark answer_score as 'good' if the final answer is correct.
Mark trajectory_score as 'good' if the tool calls were reasonable.
""".strip()

agent_judge_prompt = """
Question:
{question}

Original Answer (ground truth):
{answer_orig}

Agent Answer:
{answer_agent}

Tool Calls:
{tool_calls}
""".strip()

# %%
import json
from evaluation_utils import calc_total_price, llm_structured_retry

def evaluate_agent_answer(rec, model="gpt-5.4-mini"):
    tool_calls = rec["tool_calls"]

    if isinstance(tool_calls, str):
        tool_calls = json.loads(tool_calls)

    prompt = agent_judge_prompt.format(
        question=rec["question"],
        answer_orig=rec["answer_orig"],
        answer_agent=rec["answer_agent"],
        tool_calls=json.dumps(tool_calls, indent=2),
    )

    result, usage = llm_structured_retry(
        openai_client,
        agent_judge_instructions,
        prompt,
        AgentEvaluation,
        model=model,
    )

    return result, usage

# %%
agent_eval, usage = evaluate_agent_answer(agent_answers[0])

agent_eval
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# Cell In[42], line 1
# ----> 1 agent_eval, usage = evaluate_agent_answer(agent_answers[0])
#       2
#       3 agent_eval
#
# Cell In[35], line 8, in evaluate_agent_answer(rec, model)
#       4 def evaluate_agent_answer(rec, model="gpt-5.4-mini"):
#       5     tool_calls = rec["tool_calls"]
#       6
#       7     if isinstance(tool_calls, str):
# ----> 8         tool_calls = json.loads(tool_calls)
#       9
#      10     prompt = agent_judge_prompt.format(
#      11         question=rec["question"],
#
# File ~\AppData\Roaming\uv\python\cpython-3.14-windows-x86_64-none\Lib\json\__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     341     s = s.decode(detect_encoding(s), 'surrogatepass')
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
# --> 346     return _default_decoder.decode(s)
#     347 if cls is None:
#     348     cls = JSONDecoder
#
# File ~\AppData\Roaming\uv\python\cpython-3.14-windows-x86_64-none\Lib\json\decoder.py:345, in JSONDecoder.decode(self, s, _w)
#     340 def decode(self, s, _w=WHITESPACE.match):
#     341     """Return the Python representation of ``s`` (a ``str`` instance
#     342     containing a JSON document).
#     343
#     344     """
# --> 345     obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     346     end = _w(s, end).end()
#     347     if end != len(s):
#
# File ~\AppData\Roaming\uv\python\cpython-3.14-windows-x86_64-none\Lib\json\decoder.py:361, in JSONDecoder.raw_decode(self, s, idx)
#     352 """Decode a JSON document from ``s`` (a ``str`` beginning with
#     353 a JSON document) and return a 2-tuple of the Python
#     354 representation and the index in ``s`` where the document ended.
#    (...)    358
#     359 """
#     360 try:
# --> 361     obj, end = self.scan_once(s, idx)
#     362 except StopIteration as err:
#     363     raise JSONDecodeError("Expecting value", s, err.value) from None
#
# JSONDecodeError: Expecting property name enclosed in double quotes: line 1 column 3 (char 2)

# %%
def judge_agent_record(rec):
    agent_eval, usage = evaluate_agent_answer(rec)

    result = {
        "question": rec["question"],
        "document": rec["document"],
        "answer_score": agent_eval.answer_score,
        "answer_reasoning": agent_eval.answer_reasoning,
        "trajectory_score": agent_eval.trajectory_score,
        "trajectory_reasoning": agent_eval.trajectory_reasoning,
    }

    return result, usage

# %%
with ThreadPoolExecutor(max_workers=6) as pool:
    results = map_progress(pool, agent_answers, judge_agent_record)
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# Cell In[38], line 2
#       1 with ThreadPoolExecutor(max_workers=6) as pool:
# ----> 2     results = map_progress(pool, agent_answers, judge_agent_record)
#
# File C:\llm_zoomcamp\llm-zoomcamp-2026-code\04-evaluation\evaluation_utils.py:124, in map_progress(pool, seq, f)
#     121         futures.append(future)
#     123     for future in futures:
# --> 124         result = future.result()
#     125         results.append(result)
#     127 return results
#
# File ~\AppData\Roaming\uv\python\cpython-3.14-windows-x86_64-none\Lib\concurrent\futures\_base.py:443, in Future.result(self, timeout)
#     441     raise CancelledError()
#     442 elif self._state == FINISHED:
# --> 443     return self.__get_result()
#     445 self._condition.wait(timeout)
#     447 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# File ~\AppData\Roaming\uv\python\cpython-3.14-windows-x86_64-none\Lib\concurrent\futures\_base.py:395, in Future.__get_result(self)
#     393 if self._exception is not None:
#     394     try:
# --> 395         raise self._exception
#     396     finally:
#     397         # Break a reference cycle with the exception in self._exception
#     398         self = None
#
# File ~\AppData\Roaming\uv\python\cpython-3.14-windows-x86_64-none\Lib\concurrent\futures\thread.py:86, in _WorkItem.run(self, ctx)
#      83     return
#      85 try:
# ---> 86     result = ctx.run(self.task)
#      87 except BaseException as exc:
#      88     self.future.set_exception(exc)
#
# File ~\AppData\Roaming\uv\python\cpython-3.14-windows-x86_64-none\Lib\concurrent\futures\thread.py:73, in WorkerContext.run(self, task)
#      71 def run(self, task):
#      72     fn, args, kwargs = task
# ---> 73     return fn(*args, **kwargs)
#
# Cell In[37], line 2, in judge_agent_record(rec)
#       1 def judge_agent_record(rec):
# ----> 2     agent_eval, usage = evaluate_agent_answer(rec)
#       3
#       4     result = {
#       5         "question": rec["question"],
#
# Cell In[35], line 8, in evaluate_agent_answer(rec, model)
#       4 def evaluate_agent_answer(rec, model="gpt-5.4-mini"):
#       5     tool_calls = rec["tool_calls"]
#       6
#       7     if isinstance(tool_calls, str):
# ----> 8         tool_calls = json.loads(tool_calls)
#       9
#      10     prompt = agent_judge_prompt.format(
#      11         question=rec["question"],
#
# File ~\AppData\Roaming\uv\python\cpython-3.14-windows-x86_64-none\Lib\json\__init__.py:346, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     341     s = s.decode(detect_encoding(s), 'surrogatepass')
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
# --> 346     return _default_decoder.decode(s)
#     347 if cls is None:
#     348     cls = JSONDecoder
#
# File ~\AppData\Roaming\uv\python\cpython-3.14-windows-x86_64-none\Lib\json\decoder.py:345, in JSONDecoder.decode(self, s, _w)
#     340 def decode(self, s, _w=WHITESPACE.match):
#     341     """Return the Python representation of ``s`` (a ``str`` instance
#     342     containing a JSON document).
#     343
#     344     """
# --> 345     obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     346     end = _w(s, end).end()
#     347     if end != len(s):
#
# File ~\AppData\Roaming\uv\python\cpython-3.14-windows-x86_64-none\Lib\json\decoder.py:361, in JSONDecoder.raw_decode(self, s, idx)
#     352 """Decode a JSON document from ``s`` (a ``str`` beginning with
#     353 a JSON document) and return a 2-tuple of the Python
#     354 representation and the index in ``s`` where the document ended.
#    (...)    358
#     359 """
#     360 try:
# --> 361     obj, end = self.scan_once(s, idx)
#     362 except StopIteration as err:
#     363     raise JSONDecodeError("Expecting value", s, err.value) from None
#
# JSONDecodeError: Expecting property name enclosed in double quotes: line 1 column 3 (char 2)

# %%
agent_evaluations = []
usages = []

for evaluation, usage in results:
    agent_evaluations.append(evaluation)
    usages.append(usage)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[39], line 4
#       1 agent_evaluations = []
#       2 usages = []
#       3
# ----> 4 for evaluation, usage in results:
#       5     agent_evaluations.append(evaluation)
#       6     usages.append(usage)
#
# NameError: name 'results' is not defined
